# %%
import pandas as pd

# %%
W = pd.read_csv('weather_nyc.csv').sort_values(by=['TS_year','TS_month','TS_day','TS_hour','TS_minute'])
# Out:
# /Users/zcarwile/anaconda/envs/weather_analysis/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (5,6,9,12,14,15,19,20,22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
W.head(5)
# Out:
#         TS_year  TS_month  TS_day  TS_hour  TS_minute humidity visibility  \
# 130927     2016         7      14       17         55     0.73       8.61
# 120964     2016         7      14       18          0     0.73       8.71
# 109178     2016         7      14       18          5     0.73       8.72
# 118063     2016         7      14       18         10     0.73       8.73
# 99225      2016         7      14       18         15     0.71       8.65
#
#        nearestStormBearing        summary   ozone     ...      windSpeed  \
# 130927                   8  Partly Cloudy  320.92     ...           5.97
# 120964                   8  Partly Cloudy  320.92     ...           5.76
# 109178                  55  Partly Cloudy  320.99     ...            8.9
# 118063                  55  Partly Cloudy  321.07     ...           8.97
# 99225                   50  Partly Cloudy  321.14     ...           8.57
#
#         windBearing nearestStormDistance precipProbability  uvIndex pressure  \
# ...

# %%
W.tail(5)
# Out:
#        TS_year  TS_month  TS_day  TS_hour  TS_minute humidity visibility  \
# 88374     2017        12       5       20         10     0.79         10
# 11449     2017        12       5       20         15     0.79         10
# 89175     2017        12       5       20         20     0.79         10
# 39674     2017        12       5       20         25     0.79         10
# 82108     2017        12       5       20         30     0.79         10
#
#       nearestStormBearing     summary   ozone     ...      windSpeed  \
# 88374             No Data     Drizzle  272.35     ...            7.2
# 11449             No Data     Drizzle  272.29     ...            7.5
# 89175             No Data     Drizzle  272.23     ...            7.8
# 39674             No Data  Light Rain  272.17     ...            8.1
# 82108             No Data     Drizzle  272.11     ...            8.4
#
#        windBearing nearestStormDistance precipProbability uvIndex pressure  \
# ...

# %%
W.plot(y="temperature")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-5530f9fe0e8c> in <module>()
# ----> 1 W.plot(y="temperature")
#
# ~/anaconda/envs/weather_analysis/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2675                           fontsize=fontsize, colormap=colormap, table=table,
#    2676                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2677                           sort_columns=sort_columns, **kwds)
#    2678     __call__.__doc__ = plot_frame.__doc__
#    2679
#
# ...
